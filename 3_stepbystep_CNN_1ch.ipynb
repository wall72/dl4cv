# %% [markdown]
# ### 3-3. Filter를 이해하기

# %%
# 필요한 모듈 불러오기
import numpy as np
from scipy.signal import convolve2d # 2D convolution 연산
from skimage.io import imread, imshow # 데이터를 이미지로 보여주기
from skimage.color import rgb2gray # RGB 채널값을 가진 이미지 데이터를, 흑백 이미지의 데이터로 변환하기

# %%
cat = rgb2gray(imread('data/cat.jpg')) # read image

# %%
cat.shape
# Out:
# (3266, 4899)

# %%
cat
# Out:
# array([[0.81598392, 0.80814078, 0.88293333, ..., 0.08613451, 0.10938118,
#         0.10938118],
#        [0.76500353, 0.77284667, 0.84371765, ..., 0.06652667, 0.08977333,
#         0.0936949 ],
#        [0.78853294, 0.81206235, 0.84735647, ..., 0.04858549, 0.07829137,
#         0.09005608],
#        ...,
#        [0.70269882, 0.67132627, 0.69821176, ..., 0.87088588, 0.86724706,
#         0.87901176],
#        [0.6483702 , 0.6601349 , 0.67860392, ..., 0.89441529, 0.88265059,
#         0.87480745],
#        [0.64444863, 0.6601349 , 0.67468235, ..., 0.88265059, 0.87088588,
#         0.86304275]])

# %%
imshow(cat)
# Out:
# /tmp/ipykernel_9640/861857853.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(cat)

# %%
# Edge Detection
edge = np.array([[-1, -1, -1],
                    [-1, 8, -1],
                    [-1, -1, -1]])
# Sharpen
sharpen = np.array([[0, -1, 0],
                    [-1, 5, -1],
                    [0, -1, 0]])
# Gaussian Blur
blur = (1 / 16.0) * np.array([[1., 2., 1.],
                                 [2., 4., 2.],
                                 [1., 2., 1.]])

# %% [markdown]
# #### Edge Detection

# %%
edge_im = convolve2d(cat, edge, 'valid')

# %%
imshow(edge_im)
# Out:
# /tmp/ipykernel_9640/2655829332.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(edge_im)

# %% [markdown]
# #### Sharpen

# %%
sharp_im = convolve2d(cat, sharpen, 'valid')

# %%
imshow(sharp_im)
# Out:
# /tmp/ipykernel_9640/3140121216.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(sharp_im)

# %% [markdown]
# #### Gaussian Blur

# %%
blur_im = convolve2d(cat, blur, 'valid')

# %%
imshow(blur_im)
# Out:
# /tmp/ipykernel_9640/4263342203.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(blur_im)
